# %%
import pandas as pd
import time
from ncaa_bbStats import get_team_stat, list_all_teams, get_pythagorean_expectation

START_YEAR = 2002
END_YEAR = 2025
DIVISION = 1
OUTPUT_CSV = "ncaabb_dataset.csv"

# Miami,FL needs to be changed to University of Miami,ACC
# Miami,OH needs to be changed to Miami University-Ohio,MAC
# LMU,CA needs to be changed to LMU,WCC
# Saint Mary's,CA needs to be changed to Saint Mary's,WCC
# St. John's,NY needs to be changed to St. John's,Big East

STAT_NAMES = [
    "W", "L", "T", "WPCT", "PE", "Difference",
    "G", "BB (Batting)", "AB", "H", "BA", "DP", "DPPG", "2B", "2BPG",
    "IP", "R (Pitching)", "ER", "ERA", "PO", "A", "E", "FPCT",
    "HB", "HBP", "HA", "HAPG", "HR", "HRPG", "SF", "SH", "OBP",
    "SB", "SBPG", "CS", "R (Batting)", "RPG", "SHO", "TB", "SLG",
    "SO", "BB (Pitching)", "K/BB", "K/9", "TP", "3B", "3BPG", "WHIP", "BBPG (Pitching)"
]

rows = []

start_time = time.time()

for year in range(START_YEAR, END_YEAR + 1):
    print(f"Processing {year}...")
    try:
        teams = list_all_teams(year, DIVISION)
    except Exception as e:
        print(f"Error getting teams for {year}: {e}")
        continue
    
    for team_full in teams:
        # Split team and league
        if "(" in team_full and ")" in team_full:
            team_name = team_full.split("(")[0].strip()
            league_name = team_full.split("(")[1].replace(")", "").strip()
        else:
            continue
        
        # Skip rows where team/league name is suspiciously short or empty
        if not team_name or not league_name or team_name.lower().startswith("division"):
            continue
        
        row = {"team": team_name, "league": league_name, "year": year}
        
        # Get W, L, T, G first
        try:
            row["W"] = get_team_stat("W", team_full, year, DIVISION)
        except Exception:
            row["W"] = None
        try:
            row["L"] = get_team_stat("L", team_full, year, DIVISION)
        except Exception:
            row["L"] = None
        try:
            row["T"] = get_team_stat("T", team_full, year, DIVISION)
        except Exception:
            row["T"] = None
        try:
            row["G"] = get_team_stat("G", team_full, year, DIVISION)
        except Exception:
            row["G"] = None

        # WPCT from W / G instead of API
        if row["W"] is not None and row["G"] not in (None, 0):
            row["WPCT"] = round(row["W"] / row["G"], 3)  # 3 decimal places
        else:
            row["WPCT"] = None
    
        # Add Pythagorean expectation
        pytha_val = get_pythagorean_expectation(team_name, year, DIVISION)
        def safe_float(val):
            """Convert to float if possible, else return None."""
            try:
                return float(val)
            except (ValueError, TypeError):
                return None
                
        pytha_val = safe_float(pytha_val)
        row["PE"] = round(pytha_val, 3) if pytha_val is not None else None

        # Add difference column (WPCT - PE)
        if row["WPCT"] is not None and row["PE"] is not None:
            row["Difference"] = round(row["WPCT"] - row["PE"], 3)
        else:
            row["Difference"] = None
    
        # Remaining stats
        for stat in STAT_NAMES:
            if stat in ["W", "L", "T", "WPCT", "PE", "Difference"]:
                continue
            try:
                row[stat] = get_team_stat(stat, team_full, year, DIVISION)
            except Exception:
                row[stat] = None
        
        rows.append(row)

df = pd.DataFrame(rows)

# Remove rows where all stats are NaN/0
df = df.dropna(subset=STAT_NAMES, how="all")

# Final safety: remove any stray rows with "division" in team/league
df = df[~df["team"].str.lower().str.contains("division", na=False)]
df = df[~df["league"].str.lower().str.contains("division", na=False)]

# Convert numeric fields
for stat in STAT_NAMES:
    df[stat] = pd.to_numeric(df[stat], errors="coerce")

df.to_csv(OUTPUT_CSV, index=False)
print(f"Dataset saved to {OUTPUT_CSV} with {len(df)} rows after cleanup.")

# Print total runtime
elapsed_time = time.time() - start_time
print(f"Script completed in {elapsed_time:.2f} seconds.")
# Out:
# Processing 2002...
# Processing 2003...
# Processing 2004...
# Processing 2005...
# Processing 2006...
# Processing 2007...
# Processing 2008...
# Processing 2009...
# Processing 2010...
# Processing 2011...
# Processing 2012...
# Processing 2013...
# Processing 2014...
# Processing 2015...
# Processing 2016...
# Processing 2017...
# Processing 2018...
# Processing 2019...
# Processing 2020...
# Processing 2021...
# Processing 2022...
# Processing 2023...
# Processing 2024...
# Processing 2025...
# Dataset saved to ncaabb_dataset.csv with 6787 rows after cleanup.
# Script completed in 744.11 seconds.

# %%
import numpy as np
import pandas as pd

INPUT_CSV = "ncaabb_dataset.csv"

# columns in CSV that hold runs scored and runs allowed
RS_COL = "R (Batting)"    # runs scored
RA_COL = "R (Pitching)"   # runs allowed
WPCT_COL = "WPCT"         # actual win percentage in CSV

# grid search range for exponent
GRID_MIN, GRID_MAX, GRID_STEP = 0.5, 3.5, 0.01

# metric: RMSE
def rmse(y_true, y_pred):
    mask = ~np.isnan(y_true) & ~np.isnan(y_pred)
    if mask.sum() == 0:
        return np.nan
    return np.sqrt(np.mean((y_true[mask] - y_pred[mask]) ** 2))

df = pd.read_csv(INPUT_CSV)

# ensure numeric
for c in [RS_COL, RA_COL, WPCT_COL]:
    if c not in df.columns:
        raise KeyError(f"Column {c} not found in CSV")
    df[c] = pd.to_numeric(df[c], errors="coerce")

# remove rows with missing RS/RA/WPCT
mask = ~df[RS_COL].isna() & ~df[RA_COL].isna() & ~df[WPCT_COL].isna()
df_clean = df[mask].copy()
# Filter so it's only 2021-2025, matching player_stat years
if "year" in df_clean.columns:
    df_clean = df_clean[(df_clean["year"] >= 2021) & (df_clean["year"] <= 2025)]

print(f"Using {len(df_clean)} rows for fitting (non-missing RS/RA/WPCT).")

# convert to numpy arrays
RS = df_clean[RS_COL].to_numpy(dtype=float)
RA = df_clean[RA_COL].to_numpy(dtype=float)
WPCT = df_clean[WPCT_COL].to_numpy(dtype=float)

# Check which years remain after cleaning
print(df_clean["year"].unique())

# Safety: avoid zero runs (if both zero, skip those rows)
valid = (RS + RA) > 0
RS = RS[valid]; RA = RA[valid]; WPCT = WPCT[valid]
print(f"{len(RS)} rows after removing zero total-run rows.")

# Grid search
grid = np.arange(GRID_MIN, GRID_MAX + 1e-9, GRID_STEP)
best_x = None
best_rmse = np.inf
rmses = []

for x in grid:
    # compute predicted win% for exponent x
    with np.errstate(over='ignore', invalid='ignore'):
        RSx = np.power(RS, x)
        RAx = np.power(RA, x)
        pred = RSx / (RSx + RAx)
    cur_rmse = rmse(WPCT, pred)
    rmses.append(cur_rmse)
    if np.isfinite(cur_rmse) and cur_rmse < best_rmse:
        best_rmse = cur_rmse
        best_x = x

print(f"Grid search best exponent: {best_x:.2f} with RMSE = {best_rmse:.5f}")

# compare to MLB baseline 1.83
mlb_x = 1.83
RSx = np.power(RS, mlb_x); RAx = np.power(RA, mlb_x)
mlb_pred = RSx / (RSx + RAx)
mlb_rmse = rmse(WPCT, mlb_pred)
print(f"Baseline exponent {mlb_x} RMSE = {mlb_rmse:.5f}")
print(f"Improvement % in RMSE: {((mlb_rmse - best_rmse) / mlb_rmse) * 100:.2f}")

# Compute per-year best exponent
compute_per_year = True
per_year_results = {}
if compute_per_year and "year" in df_clean.columns:
    for year, group in df_clean.groupby("year"):
        RSy = group[RS_COL].to_numpy(dtype=float)
        RAy = group[RA_COL].to_numpy(dtype=float)
        WPCTy = group[WPCT_COL].to_numpy(dtype=float)
        valid = (RSy + RAy) > 0
        RSy = RSy[valid]; RAy = RAy[valid]; WPCTy = WPCTy[valid]
        if len(RSy) < 10:  # skip tiny years
            continue
        
        # Find best exponent
        best_x_y = None
        best_rmse_y = np.inf
        for x in grid:
            RSx = np.power(RSy, x)
            RAx = np.power(RAy, x)
            pred = RSx / (RSx + RAx)
            cur_rmse = rmse(WPCTy, pred)
            if np.isfinite(cur_rmse) and cur_rmse < best_rmse_y:
                best_rmse_y = cur_rmse
                best_x_y = x
        
        # Calculate MLB 1.83 RMSE
        RSx_mlb = np.power(RSy, 1.83)
        RAx_mlb = np.power(RAy, 1.83)
        pred_mlb = RSx_mlb / (RSx_mlb + RAx_mlb)
        mlb_rmse_y = rmse(WPCTy, pred_mlb)
        
        # improvement %
        improvement_pct = ((mlb_rmse_y - best_rmse_y) / mlb_rmse_y) * 100
        
        # Results (best exponent, best RMSE, MLB RMSE, improvement %)
        per_year_results[year] = (best_x_y, best_rmse_y, mlb_rmse_y, improvement_pct)

    print("Per-year top exponents (sample):")
    for year in sorted(per_year_results.keys()):
        best_x_y, best_rmse_y, mlb_rmse_y, improvement_pct = per_year_results[year]
        print(
            int(year),
            (
                float(round(best_x_y, 3)),
                float(round(best_rmse_y, 4)),
                1.83,
                float(round(mlb_rmse_y, 4)),
                float(round(improvement_pct, 2))
            )
        )
# Out:
# Using 1468 rows for fitting (non-missing RS/RA/WPCT).
# [2021 2022 2023 2024 2025]
# 1468 rows after removing zero total-run rows.
# Grid search best exponent: 1.79 with RMSE = 0.04586
# Baseline exponent 1.83 RMSE = 0.04594
# Improvement % in RMSE: 0.16
# Per-year top exponents (sample):
# 2021 (1.71, 0.0479, 1.83, 0.0486, 1.4)
# 2022 (1.77, 0.0443, 1.83, 0.0445, 0.41)
# 2023 (1.83, 0.0443, 1.83, 0.0443, -0.0)
# 2024 (1.85, 0.0446, 1.83, 0.0446, 0.02)
# 2025 (1.8, 0.0476, 1.83, 0.0476, 0.07)

# %%
import numpy as np
import pandas as pd

INPUT_CSV = "ncaabb_dataset.csv"

# columns in CSV that hold runs scored and runs allowed
RS_COL = "R (Batting)"    # runs scored
RA_COL = "R (Pitching)"   # runs allowed
WPCT_COL = "WPCT"         # actual win percentage in CSV

# grid search range for exponent
GRID_MIN, GRID_MAX, GRID_STEP = 0.5, 3.5, 0.01

# metric: RMSE
def rmse(y_true, y_pred):
    mask = ~np.isnan(y_true) & ~np.isnan(y_pred)
    if mask.sum() == 0:
        return np.nan
    return np.sqrt(np.mean((y_true[mask] - y_pred[mask]) ** 2))

df = pd.read_csv(INPUT_CSV)

# ensure numeric
for c in [RS_COL, RA_COL, WPCT_COL]:
    if c not in df.columns:
        raise KeyError(f"Column {c} not found in CSV")
    df[c] = pd.to_numeric(df[c], errors="coerce")

# remove rows with missing RS/RA/WPCT
mask = ~df[RS_COL].isna() & ~df[RA_COL].isna() & ~df[WPCT_COL].isna()
df_clean = df[mask].copy()
# Filter so it's only 2021-2025, matching player_stat years
if "year" in df_clean.columns:
    df_clean = df_clean[(df_clean["year"] >= 2021) & (df_clean["year"] <= 2025)]
    
print(f"Using {len(df_clean)} rows for fitting (non-missing RS/RA/WPCT).")

# convert to numpy arrays
RS = df_clean[RS_COL].to_numpy(dtype=float)
RA = df_clean[RA_COL].to_numpy(dtype=float)
WPCT = df_clean[WPCT_COL].to_numpy(dtype=float)

# Check which years remain after cleaning
print(df_clean["year"].unique())

# safety: avoid zero runs (if both zero, skip those rows)
valid = (RS + RA) > 0
RS = RS[valid]; RA = RA[valid]; WPCT = WPCT[valid]
print(f"{len(RS)} rows after removing zero total-run rows.")

# Grid search
grid = np.arange(GRID_MIN, GRID_MAX + 1e-9, GRID_STEP)
best_x = None
best_rmse = np.inf
rmses = []

for x in grid:
    # compute predicted win% for exponent x
    with np.errstate(over='ignore', invalid='ignore'):
        RSx = np.power(RS, x)
        RAx = np.power(RA, x)
        pred = RSx / (RSx + RAx)
    cur_rmse = rmse(WPCT, pred)
    rmses.append(cur_rmse)
    if np.isfinite(cur_rmse) and cur_rmse < best_rmse:
        best_rmse = cur_rmse
        best_x = x

print(f"Grid search best exponent: {best_x:.2f} with RMSE = {best_rmse:.5f}")

# compare to MLB baseline 1.83
mlb_x = 1.83
RSx = np.power(RS, mlb_x); RAx = np.power(RA, mlb_x)
mlb_pred = RSx / (RSx + RAx)
mlb_rmse = rmse(WPCT, mlb_pred)
print(f"Baseline exponent {mlb_x} RMSE = {mlb_rmse:.5f}")
print(f"Improvement % in RMSE: {((mlb_rmse - best_rmse) / mlb_rmse) * 100:.2f}")

# Compute per-year & per-conference best exponent
compute_per_conf = True
per_conf_results = {}

if compute_per_conf and "year" in df_clean.columns and "league" in df_clean.columns:
    for year, year_group in df_clean.groupby("year"):
        for conf, group in year_group.groupby("league"):
            RSy = group[RS_COL].to_numpy(dtype=float)
            RAy = group[RA_COL].to_numpy(dtype=float)
            WPCTy = group[WPCT_COL].to_numpy(dtype=float)
            
            # filter invalid games
            valid = (RSy + RAy) > 0
            RSy = RSy[valid]; RAy = RAy[valid]; WPCTy = WPCTy[valid]
            if len(RSy) < 3:  # skip tiny samples
                continue
            
            # Find best exponent
            best_x_c = None
            best_rmse_c = np.inf
            for x in grid:
                RSx = np.power(RSy, x)
                RAx = np.power(RAy, x)
                pred = RSx / (RSx + RAx)
                cur_rmse = rmse(WPCTy, pred)
                if np.isfinite(cur_rmse) and cur_rmse < best_rmse_c:
                    best_rmse_c = cur_rmse
                    best_x_c = x
            
            # MLB 1.83 RMSE
            RSx_mlb = np.power(RSy, 1.83)
            RAx_mlb = np.power(RAy, 1.83)
            pred_mlb = RSx_mlb / (RSx_mlb + RAx_mlb)
            mlb_rmse_c = rmse(WPCTy, pred_mlb)
            
            # improvement in RMSE
            improvement_pct = ((mlb_rmse_c - best_rmse_c) / mlb_rmse_c) * 100
            
            # results
            per_conf_results[(year, conf)] = (best_x_c, best_rmse_c, mlb_rmse_c, improvement_pct)

    print("Per-year per-conference top exponents:")
    for (year, conf), vals in sorted(per_conf_results.items()):
        best_x_c, best_rmse_c, mlb_rmse_c, improvement_pct = vals
        print(
            int(year),
            conf,
            (
                float(round(best_x_c, 3)),
                float(round(best_rmse_c, 4)),
                1.83,
                float(round(mlb_rmse_c, 4)),
                float(round(improvement_pct, 2))
            )
        )

# Find biggest difference from 1.83 across all (year, conference)
max_diff = -1
max_record = None

for (year, conf), (best_x_c, best_rmse_c, mlb_rmse_c, improvement_pct) in per_conf_results.items():
    diff = abs(best_x_c - 1.83)
    if diff > max_diff:
        max_diff = diff
        max_record = (year, conf, best_x_c, improvement_pct)

if max_record:
    year, conf, best_x_c, improvement_pct = max_record
    print(f"\nLargest deviation from 1.83: {year} in league {conf} with best_x = {best_x_c:.2f}, {improvement_pct:.2f}% improvement")
# Out:
# Using 1468 rows for fitting (non-missing RS/RA/WPCT).
# [2021 2022 2023 2024 2025]
# 1468 rows after removing zero total-run rows.
# Grid search best exponent: 1.79 with RMSE = 0.04586
# Baseline exponent 1.83 RMSE = 0.04594
# Improvement % in RMSE: 0.16
# Per-year per-conference top exponents:
# 2021 ACC (1.78, 0.0404, 1.83, 0.0405, 0.12)
# 2021 ASUN (1.77, 0.0371, 1.83, 0.0373, 0.49)
# 2021 America East (1.31, 0.0396, 1.83, 0.0463, 14.44)
# 2021 Atlantic 10 (2.02, 0.0374, 1.83, 0.0389, 4.06)
# 2021 Big 12 (1.43, 0.0402, 1.83, 0.0513, 21.63)
# 2021 Big East (1.58, 0.0503, 1.83, 0.0532, 5.45)
# 2021 Big South (1.78, 0.0556, 1.83, 0.0557, 0.13)
# 2021 Big Ten (1.65, 0.0289, 1.83, 0.0313, 7.8)
# 2021 Big West (1.66, 0.0325, 1.83, 0.0354, 7.96)
# 2021 CAA (1.74, 0.026, 1.83, 0.0267, 2.55)
# 2021 CUSA (1.78, 0.059, 1.83, 0.0591, 0.18)
# 2021 Horizon (1.56, 0.0233, 1.83, 0.0329, 29.25)
# 2021 MAAC (1.67, 0.0718, 1.83, 0.0731, 1.77)
# 2021 MAC (1.68, 0.0447, 1.83, 0.0458, 2.29)
# 2021 MEAC (1.88, 0.0577, 1.83, 0.0578, 0.14)
# 2021 MVC (1.81, 0.0308, 1.83, 0.0308, 0.1)
# 2021 Mountain West (2.11, 0.0543, 1.83, 0.0568, 4.34)
# 2021 NEC (1.61, 0.0486, 1.83, 0.0527, 7.8)
# 2021 OVC (1.18, 0.05, 1.83, 0.0555, 9.83)
# 2021 Pac-12 (1.72, 0.044, 1.83, 0.0446, 1.45)
# 2021 Patriot (2.53, 0.0573, 1.83, 0.0617, 7.25)
# 2021 SEC (1.93, 0.0421, 1.83, 0.0428, 1.54)
# 2021 SWAC (1.55, 0.0664, 1.83, 0.0726, 8.54)
# 2021 SoCon (1.7, 0.0434, 1.83, 0.0442, 1.79)
# 2021 Southland (1.42, 0.0449, 1.83, 0.0499, 9.97)
# 2021 Summit League (1.81, 0.0703, 1.83, 0.0704, 0.02)
# 2021 Sun Belt (1.61, 0.0268, 1.83, 0.0294, 8.65)
# 2021 The American (1.81, 0.0203, 1.83, 0.0203, 0.17)
# 2021 WAC (2.07, 0.0534, 1.83, 0.0564, 5.37)
# 2021 WCC (1.8, 0.0532, 1.83, 0.0532, 0.04)
# 2022 ACC (1.63, 0.0306, 1.83, 0.0346, 11.43)
# 2022 ASUN (1.75, 0.0356, 1.83, 0.0358, 0.41)
# 2022 America East (1.67, 0.0467, 1.83, 0.0472, 1.11)
# 2022 Atlantic 10 (1.87, 0.0378, 1.83, 0.0379, 0.26)
# 2022 Big 12 (1.56, 0.0311, 1.83, 0.0365, 14.75)
# 2022 Big East (1.68, 0.0325, 1.83, 0.0342, 4.99)
# 2022 Big South (1.79, 0.0377, 1.83, 0.0378, 0.31)
# 2022 Big Ten (1.78, 0.0501, 1.83, 0.0502, 0.21)
# 2022 Big West (2.08, 0.0411, 1.83, 0.045, 8.79)
# 2022 CAA (1.54, 0.0479, 1.83, 0.0502, 4.55)
# 2022 CUSA (1.75, 0.0496, 1.83, 0.0499, 0.71)
# 2022 Horizon (1.6, 0.0375, 1.83, 0.0398, 5.69)
# 2022 Ivy League (1.88, 0.0669, 1.83, 0.067, 0.18)
# 2022 MAAC (1.79, 0.0318, 1.83, 0.0319, 0.43)
# 2022 MAC (1.83, 0.0498, 1.83, 0.0498, -0.0)
# 2022 MEAC (1.72, 0.0447, 1.83, 0.0453, 1.3)
# 2022 MVC (2.11, 0.0435, 1.83, 0.0457, 4.7)
# 2022 Mountain West (1.45, 0.0528, 1.83, 0.0561, 5.95)
# 2022 NEC (2.13, 0.0429, 1.83, 0.0473, 9.38)
# 2022 OVC (2.3, 0.0256, 1.83, 0.0346, 26.03)
# 2022 Pac-12 (1.67, 0.0338, 1.83, 0.035, 3.55)
# 2022 Patriot (1.24, 0.0278, 1.83, 0.0549, 49.46)
# 2022 SEC (1.53, 0.0347, 1.83, 0.0417, 16.62)
# 2022 SWAC (1.65, 0.0527, 1.83, 0.0543, 2.82)
# 2022 SoCon (2.01, 0.0427, 1.83, 0.0439, 2.88)
# 2022 Southland (1.19, 0.0308, 1.83, 0.0478, 35.65)
# 2022 Summit League (1.99, 0.0546, 1.83, 0.056, 2.55)
# 2022 Sun Belt (1.99, 0.0451, 1.83, 0.0465, 3.06)
# 2022 The American (1.92, 0.0415, 1.83, 0.0417, 0.48)
# 2022 WAC (1.95, 0.035, 1.83, 0.0356, 1.91)
# 2022 WCC (1.94, 0.0409, 1.83, 0.0414, 1.03)
# 2023 ACC (1.5, 0.0404, 1.83, 0.048, 15.88)
# 2023 ASUN (2.11, 0.0401, 1.83, 0.0418, 3.96)
# 2023 America East (2.31, 0.0422, 1.83, 0.049, 13.82)
# 2023 Atlantic 10 (1.89, 0.0301, 1.83, 0.0303, 0.62)
# 2023 Big 12 (1.66, 0.0219, 1.83, 0.0249, 12.26)
# 2023 Big East (1.89, 0.0427, 1.83, 0.0429, 0.49)
# 2023 Big South (1.93, 0.0271, 1.83, 0.0279, 2.98)
# 2023 Big Ten (1.77, 0.0468, 1.83, 0.047, 0.33)
# 2023 Big West (1.92, 0.027, 1.83, 0.0277, 2.59)
# 2023 CAA (1.63, 0.0447, 1.83, 0.0463, 3.52)
# 2023 CUSA (2.07, 0.0237, 1.83, 0.0273, 13.23)
# 2023 Horizon (1.94, 0.0394, 1.83, 0.0401, 1.59)
# 2023 Ivy League (2.13, 0.0458, 1.83, 0.0507, 9.55)
# 2023 MAAC (1.88, 0.042, 1.83, 0.0422, 0.41)
# 2023 MAC (1.89, 0.0504, 1.83, 0.0505, 0.29)
# 2023 MVC (1.91, 0.0354, 1.83, 0.0356, 0.62)
# 2023 Mountain West (0.92, 0.0513, 1.83, 0.0621, 17.35)
# 2023 NEC (1.99, 0.0474, 1.83, 0.0487, 2.64)
# 2023 OVC (2.44, 0.0425, 1.83, 0.0482, 11.72)
# 2023 Pac-12 (1.71, 0.0473, 1.83, 0.0479, 1.15)
# 2023 Patriot (1.57, 0.0495, 1.83, 0.0532, 7.02)
# 2023 SEC (1.66, 0.0412, 1.83, 0.0433, 4.83)
# 2023 SWAC (1.82, 0.03, 1.83, 0.03, 0.02)
# 2023 SoCon (1.71, 0.0442, 1.83, 0.0446, 0.76)
# 2023 Southland (1.81, 0.0319, 1.83, 0.0319, 0.07)
# 2023 Summit League (1.89, 0.0471, 1.83, 0.0474, 0.61)
# 2023 Sun Belt (2.0, 0.0488, 1.83, 0.0496, 1.64)
# 2023 The American (1.89, 0.0573, 1.83, 0.0574, 0.16)
# 2023 WAC (1.63, 0.0623, 1.83, 0.063, 1.12)
# 2023 WCC (1.78, 0.0476, 1.83, 0.0476, 0.19)
# 2024 ACC (1.82, 0.0435, 1.83, 0.0435, 0.0)
# 2024 ASUN (1.77, 0.0277, 1.83, 0.0279, 0.6)
# 2024 America East (1.89, 0.0476, 1.83, 0.0478, 0.31)
# 2024 Atlantic 10 (1.74, 0.0254, 1.83, 0.0258, 1.62)
# 2024 Big 12 (1.58, 0.0371, 1.83, 0.04, 7.22)
# 2024 Big East (1.86, 0.0406, 1.83, 0.0406, 0.1)
# 2024 Big South (1.91, 0.0342, 1.83, 0.0343, 0.52)
# 2024 Big Ten (1.48, 0.0448, 1.83, 0.0477, 6.08)
# 2024 Big West (2.1, 0.0423, 1.83, 0.0467, 9.47)
# 2024 CAA (1.76, 0.0301, 1.83, 0.0304, 1.04)
# 2024 CUSA (2.07, 0.0544, 1.83, 0.0561, 3.08)
# 2024 Horizon (1.79, 0.0414, 1.83, 0.0414, 0.18)
# 2024 Ivy League (1.74, 0.0613, 1.83, 0.0615, 0.38)
# 2024 MAAC (2.1, 0.0419, 1.83, 0.0457, 8.37)
# 2024 MAC (2.1, 0.048, 1.83, 0.0504, 4.75)
# 2024 MVC (2.37, 0.0518, 1.83, 0.0599, 13.56)
# 2024 Mountain West (1.76, 0.0277, 1.83, 0.0278, 0.53)
# 2024 NEC (2.15, 0.0576, 1.83, 0.0615, 6.35)
# 2024 OVC (1.8, 0.0418, 1.83, 0.0418, 0.09)
# 2024 Pac-12 (2.08, 0.0324, 1.83, 0.0352, 7.8)
# 2024 Patriot (1.24, 0.017, 1.83, 0.0418, 59.26)
# 2024 SEC (1.9, 0.0382, 1.83, 0.0385, 0.83)
# 2024 SWAC (1.75, 0.0628, 1.83, 0.063, 0.34)
# 2024 SoCon (1.69, 0.0257, 1.83, 0.0269, 4.58)
# 2024 Southland (1.59, 0.0512, 1.83, 0.0534, 4.09)
# 2024 Summit League (2.07, 0.0515, 1.83, 0.0531, 3.18)
# 2024 Sun Belt (1.65, 0.0464, 1.83, 0.0475, 2.41)
# 2024 The American (1.73, 0.0263, 1.83, 0.0268, 1.79)
# 2024 WAC (1.7, 0.038, 1.83, 0.039, 2.42)
# 2024 WCC (1.77, 0.0438, 1.83, 0.044, 0.58)
# 2025 ACC (1.76, 0.0414, 1.83, 0.0416, 0.62)
# 2025 ASUN (1.91, 0.0231, 1.83, 0.0238, 2.61)
# 2025 America East (1.73, 0.034, 1.83, 0.0344, 1.24)
# 2025 Atlantic 10 (1.69, 0.0373, 1.83, 0.0382, 2.29)
# 2025 Big 12 (1.66, 0.0646, 1.83, 0.0653, 1.14)
# 2025 Big East (2.16, 0.0434, 1.83, 0.0477, 9.01)
# 2025 Big South (1.58, 0.0434, 1.83, 0.0479, 9.33)
# 2025 Big Ten (1.45, 0.0452, 1.83, 0.0514, 11.95)
# 2025 Big West (1.9, 0.0434, 1.83, 0.0437, 0.57)
# 2025 CAA (1.7, 0.0342, 1.83, 0.0354, 3.38)
# 2025 CUSA (1.78, 0.0286, 1.83, 0.0288, 0.65)
# 2025 Horizon (2.47, 0.0317, 1.83, 0.0533, 40.55)
# 2025 Ivy League (1.58, 0.031, 1.83, 0.0382, 18.68)
# 2025 MAAC (1.81, 0.0609, 1.83, 0.0609, 0.02)
# 2025 MAC (2.19, 0.0548, 1.83, 0.0577, 5.02)
# 2025 MVC (2.12, 0.0362, 1.83, 0.0408, 11.31)
# 2025 Mountain West (1.85, 0.045, 1.83, 0.045, 0.01)
# 2025 NEC (2.12, 0.0739, 1.83, 0.0778, 5.01)
# 2025 OVC (2.19, 0.0436, 1.83, 0.0475, 8.11)
# 2025 Patriot (1.65, 0.0418, 1.83, 0.0428, 2.36)
# 2025 SEC (1.6, 0.0542, 1.83, 0.0584, 7.23)
# 2025 SWAC (2.1, 0.0308, 1.83, 0.0359, 14.14)
# 2025 SoCon (1.19, 0.0536, 1.83, 0.0656, 18.22)
# 2025 Southland (1.79, 0.0369, 1.83, 0.037, 0.23)
# 2025 Summit League (2.25, 0.0472, 1.83, 0.0528, 10.64)
# 2025 Sun Belt (1.88, 0.0392, 1.83, 0.0393, 0.23)
# 2025 The American (2.12, 0.0415, 1.83, 0.0446, 6.84)
# 2025 WAC (1.3, 0.0471, 1.83, 0.0522, 9.86)
# 2025 WCC (1.63, 0.0256, 1.83, 0.028, 8.54)
#
# Largest deviation from 1.83: 2023 in league Mountain West with best_x = 0.92, 17.35% improvement

# %%
import numpy as np
import pandas as pd

RS_COL = "R (Batting)"
RA_COL = "R (Pitching)"
WPCT_COL = "WPCT"
GRID_MIN, GRID_MAX, GRID_STEP = 0.5, 3.5, 0.01

def rmse(y_true, y_pred):
    mask = ~np.isnan(y_true) & ~np.isnan(y_pred)
    if mask.sum() == 0:
        return np.nan
    return np.sqrt(np.mean((y_true[mask] - y_pred[mask]) ** 2))

df = pd.read_csv("ncaabb_dataset.csv")

# numeric conversion + cleaning
for c in [RS_COL, RA_COL, WPCT_COL]:
    df[c] = pd.to_numeric(df[c], errors="coerce")

df_clean = df.dropna(subset=[RS_COL, RA_COL, WPCT_COL])

# Filter so it's only 2021-2025, matching player_stat years
if "year" in df_clean.columns:
    df_clean = df_clean[(df_clean["year"] >= 2021) & (df_clean["year"] <= 2025)]

grid = np.arange(GRID_MIN, GRID_MAX + 1e-9, GRID_STEP)

# Best exponent per year
per_year_results = {}
for year, group in df_clean.groupby("year"):
    RSy, RAy, WPCTy = (
        group[RS_COL].to_numpy(float),
        group[RA_COL].to_numpy(float),
        group[WPCT_COL].to_numpy(float),
    )
    valid = (RSy + RAy) > 0
    RSy, RAy, WPCTy = RSy[valid], RAy[valid], WPCTy[valid]
    if len(RSy) < 3:
        continue
    
    best_x, best_rmse = None, np.inf
    for x in grid:
        pred = np.power(RSy, x) / (np.power(RSy, x) + np.power(RAy, x))
        cur_rmse = rmse(WPCTy, pred)
        if np.isfinite(cur_rmse) and cur_rmse < best_rmse:
            best_rmse, best_x = cur_rmse, x
    per_year_results[year] = best_x

# Best exponent per (year, conference)
per_conf_results = {}
for (year, conf), group in df_clean.groupby(["year", "league"]):
    RSy, RAy, WPCTy = (
        group[RS_COL].to_numpy(float),
        group[RA_COL].to_numpy(float),
        group[WPCT_COL].to_numpy(float),
    )
    valid = (RSy + RAy) > 0
    RSy, RAy, WPCTy = RSy[valid], RAy[valid], WPCTy[valid]
    if len(RSy) < 3:
        continue
    
    best_x, best_rmse = None, np.inf
    for x in grid:
        pred = np.power(RSy, x) / (np.power(RSy, x) + np.power(RAy, x))
        cur_rmse = rmse(WPCTy, pred)
        if np.isfinite(cur_rmse) and cur_rmse < best_rmse:
            best_rmse, best_x = cur_rmse, x
    per_conf_results[(year, conf)] = best_x

# Differences (conference – year)
diffs = {}
for (year, conf), conf_x in per_conf_results.items():
    if year in per_year_results:
        year_x = per_year_results[year]
        diff = round(conf_x - year_x, 3)
        diffs[(year, conf)] = (year_x, conf_x, diff)

# Print
print("\nConference vs Yearly Exponent Differences:")
for (year, conf), (year_x, conf_x, diff) in sorted(diffs.items()):
    print(
        f"In {year}, the best exponent was {year_x:.2f}. "
        f"For {conf}, it was {conf_x:.2f}, which is a difference of {diff:+.2f}."
    )

print("\nAverage differences by conference:")
conf_diffs_summary = {}
for (year, conf), (_, _, diff) in diffs.items():
    conf_diffs_summary.setdefault(conf, []).append(diff)

for conf, diff_list in conf_diffs_summary.items():
    avg_diff = np.mean(diff_list)
    std_diff = np.std(diff_list)
    print(f"{conf}: avg diff = {avg_diff:+.3f}, std = {std_diff:.3f}, n={len(diff_list)}")
# Out:
# Conference vs Yearly Exponent Differences:
# In 2021, the best exponent was 1.71. For ACC, it was 1.78, which is a difference of +0.07.
# In 2021, the best exponent was 1.71. For ASUN, it was 1.77, which is a difference of +0.06.
# In 2021, the best exponent was 1.71. For America East, it was 1.31, which is a difference of -0.40.
# In 2021, the best exponent was 1.71. For Atlantic 10, it was 2.02, which is a difference of +0.31.
# In 2021, the best exponent was 1.71. For Big 12, it was 1.43, which is a difference of -0.28.
# In 2021, the best exponent was 1.71. For Big East, it was 1.58, which is a difference of -0.13.
# In 2021, the best exponent was 1.71. For Big South, it was 1.78, which is a difference of +0.07.
# In 2021, the best exponent was 1.71. For Big Ten, it was 1.65, which is a difference of -0.06.
# In 2021, the best exponent was 1.71. For Big West, it was 1.66, which is a difference of -0.05.
# In 2021, the best exponent was 1.71. For CAA, it was 1.74, which is a difference of +0.03.
# In 2021, the best exponent was 1.71. For CUSA, it was 1.78, which is a difference of +0.07.
# In 2021, the best exponent was 1.71. For Horizon, it was 1.56, which is a difference of -0.15.
# In 2021, the best exponent was 1.71. For MAAC, it was 1.67, which is a difference of -0.04.
# In 2021, the best exponent was 1.71. For MAC, it was 1.68, which is a difference of -0.03.
# In 2021, the best exponent was 1.71. For MEAC, it was 1.88, which is a difference of +0.17.
# In 2021, the best exponent was 1.71. For MVC, it was 1.81, which is a difference of +0.10.
# In 2021, the best exponent was 1.71. For Mountain West, it was 2.11, which is a difference of +0.40.
# In 2021, the best exponent was 1.71. For NEC, it was 1.61, which is a difference of -0.10.
# In 2021, the best exponent was 1.71. For OVC, it was 1.18, which is a difference of -0.53.
# In 2021, the best exponent was 1.71. For Pac-12, it was 1.72, which is a difference of +0.01.
# In 2021, the best exponent was 1.71. For Patriot, it was 2.53, which is a difference of +0.82.
# In 2021, the best exponent was 1.71. For SEC, it was 1.93, which is a difference of +0.22.
# In 2021, the best exponent was 1.71. For SWAC, it was 1.55, which is a difference of -0.16.
# In 2021, the best exponent was 1.71. For SoCon, it was 1.70, which is a difference of -0.01.
# In 2021, the best exponent was 1.71. For Southland, it was 1.42, which is a difference of -0.29.
# In 2021, the best exponent was 1.71. For Summit League, it was 1.81, which is a difference of +0.10.
# In 2021, the best exponent was 1.71. For Sun Belt, it was 1.61, which is a difference of -0.10.
# In 2021, the best exponent was 1.71. For The American, it was 1.81, which is a difference of +0.10.
# In 2021, the best exponent was 1.71. For WAC, it was 2.07, which is a difference of +0.36.
# In 2021, the best exponent was 1.71. For WCC, it was 1.80, which is a difference of +0.09.
# In 2022, the best exponent was 1.77. For ACC, it was 1.63, which is a difference of -0.14.
# In 2022, the best exponent was 1.77. For ASUN, it was 1.75, which is a difference of -0.02.
# In 2022, the best exponent was 1.77. For America East, it was 1.67, which is a difference of -0.10.
# In 2022, the best exponent was 1.77. For Atlantic 10, it was 1.87, which is a difference of +0.10.
# In 2022, the best exponent was 1.77. For Big 12, it was 1.56, which is a difference of -0.21.
# In 2022, the best exponent was 1.77. For Big East, it was 1.68, which is a difference of -0.09.
# In 2022, the best exponent was 1.77. For Big South, it was 1.79, which is a difference of +0.02.
# In 2022, the best exponent was 1.77. For Big Ten, it was 1.78, which is a difference of +0.01.
# In 2022, the best exponent was 1.77. For Big West, it was 2.08, which is a difference of +0.31.
# In 2022, the best exponent was 1.77. For CAA, it was 1.54, which is a difference of -0.23.
# In 2022, the best exponent was 1.77. For CUSA, it was 1.75, which is a difference of -0.02.
# In 2022, the best exponent was 1.77. For Horizon, it was 1.60, which is a difference of -0.17.
# In 2022, the best exponent was 1.77. For Ivy League, it was 1.88, which is a difference of +0.11.
# In 2022, the best exponent was 1.77. For MAAC, it was 1.79, which is a difference of +0.02.
# In 2022, the best exponent was 1.77. For MAC, it was 1.83, which is a difference of +0.06.
# In 2022, the best exponent was 1.77. For MEAC, it was 1.72, which is a difference of -0.05.
# In 2022, the best exponent was 1.77. For MVC, it was 2.11, which is a difference of +0.34.
# In 2022, the best exponent was 1.77. For Mountain West, it was 1.45, which is a difference of -0.32.
# In 2022, the best exponent was 1.77. For NEC, it was 2.13, which is a difference of +0.36.
# In 2022, the best exponent was 1.77. For OVC, it was 2.30, which is a difference of +0.53.
# In 2022, the best exponent was 1.77. For Pac-12, it was 1.67, which is a difference of -0.10.
# In 2022, the best exponent was 1.77. For Patriot, it was 1.24, which is a difference of -0.53.
# In 2022, the best exponent was 1.77. For SEC, it was 1.53, which is a difference of -0.24.
# In 2022, the best exponent was 1.77. For SWAC, it was 1.65, which is a difference of -0.12.
# In 2022, the best exponent was 1.77. For SoCon, it was 2.01, which is a difference of +0.24.
# In 2022, the best exponent was 1.77. For Southland, it was 1.19, which is a difference of -0.58.
# In 2022, the best exponent was 1.77. For Summit League, it was 1.99, which is a difference of +0.22.
# In 2022, the best exponent was 1.77. For Sun Belt, it was 1.99, which is a difference of +0.22.
# In 2022, the best exponent was 1.77. For The American, it was 1.92, which is a difference of +0.15.
# In 2022, the best exponent was 1.77. For WAC, it was 1.95, which is a difference of +0.18.
# In 2022, the best exponent was 1.77. For WCC, it was 1.94, which is a difference of +0.17.
# In 2023, the best exponent was 1.83. For ACC, it was 1.50, which is a difference of -0.33.
# In 2023, the best exponent was 1.83. For ASUN, it was 2.11, which is a difference of +0.28.
# In 2023, the best exponent was 1.83. For America East, it was 2.31, which is a difference of +0.48.
# In 2023, the best exponent was 1.83. For Atlantic 10, it was 1.89, which is a difference of +0.06.
# In 2023, the best exponent was 1.83. For Big 12, it was 1.66, which is a difference of -0.17.
# In 2023, the best exponent was 1.83. For Big East, it was 1.89, which is a difference of +0.06.
# In 2023, the best exponent was 1.83. For Big South, it was 1.93, which is a difference of +0.10.
# In 2023, the best exponent was 1.83. For Big Ten, it was 1.77, which is a difference of -0.06.
# In 2023, the best exponent was 1.83. For Big West, it was 1.92, which is a difference of +0.09.
# In 2023, the best exponent was 1.83. For CAA, it was 1.63, which is a difference of -0.20.
# In 2023, the best exponent was 1.83. For CUSA, it was 2.07, which is a difference of +0.24.
# In 2023, the best exponent was 1.83. For Horizon, it was 1.94, which is a difference of +0.11.
# In 2023, the best exponent was 1.83. For Ivy League, it was 2.13, which is a difference of +0.30.
# In 2023, the best exponent was 1.83. For MAAC, it was 1.88, which is a difference of +0.05.
# In 2023, the best exponent was 1.83. For MAC, it was 1.89, which is a difference of +0.06.
# In 2023, the best exponent was 1.83. For MVC, it was 1.91, which is a difference of +0.08.
# In 2023, the best exponent was 1.83. For Mountain West, it was 0.92, which is a difference of -0.91.
# In 2023, the best exponent was 1.83. For NEC, it was 1.99, which is a difference of +0.16.
# In 2023, the best exponent was 1.83. For OVC, it was 2.44, which is a difference of +0.61.
# In 2023, the best exponent was 1.83. For Pac-12, it was 1.71, which is a difference of -0.12.
# In 2023, the best exponent was 1.83. For Patriot, it was 1.57, which is a difference of -0.26.
# In 2023, the best exponent was 1.83. For SEC, it was 1.66, which is a difference of -0.17.
# In 2023, the best exponent was 1.83. For SWAC, it was 1.82, which is a difference of -0.01.
# In 2023, the best exponent was 1.83. For SoCon, it was 1.71, which is a difference of -0.12.
# In 2023, the best exponent was 1.83. For Southland, it was 1.81, which is a difference of -0.02.
# In 2023, the best exponent was 1.83. For Summit League, it was 1.89, which is a difference of +0.06.
# In 2023, the best exponent was 1.83. For Sun Belt, it was 2.00, which is a difference of +0.17.
# In 2023, the best exponent was 1.83. For The American, it was 1.89, which is a difference of +0.06.
# In 2023, the best exponent was 1.83. For WAC, it was 1.63, which is a difference of -0.20.
# In 2023, the best exponent was 1.83. For WCC, it was 1.78, which is a difference of -0.05.
# In 2024, the best exponent was 1.85. For ACC, it was 1.82, which is a difference of -0.03.
# In 2024, the best exponent was 1.85. For ASUN, it was 1.77, which is a difference of -0.08.
# In 2024, the best exponent was 1.85. For America East, it was 1.89, which is a difference of +0.04.
# In 2024, the best exponent was 1.85. For Atlantic 10, it was 1.74, which is a difference of -0.11.
# In 2024, the best exponent was 1.85. For Big 12, it was 1.58, which is a difference of -0.27.
# In 2024, the best exponent was 1.85. For Big East, it was 1.86, which is a difference of +0.01.
# In 2024, the best exponent was 1.85. For Big South, it was 1.91, which is a difference of +0.06.
# In 2024, the best exponent was 1.85. For Big Ten, it was 1.48, which is a difference of -0.37.
# In 2024, the best exponent was 1.85. For Big West, it was 2.10, which is a difference of +0.25.
# In 2024, the best exponent was 1.85. For CAA, it was 1.76, which is a difference of -0.09.
# In 2024, the best exponent was 1.85. For CUSA, it was 2.07, which is a difference of +0.22.
# In 2024, the best exponent was 1.85. For Horizon, it was 1.79, which is a difference of -0.06.
# In 2024, the best exponent was 1.85. For Ivy League, it was 1.74, which is a difference of -0.11.
# In 2024, the best exponent was 1.85. For MAAC, it was 2.10, which is a difference of +0.25.
# In 2024, the best exponent was 1.85. For MAC, it was 2.10, which is a difference of +0.25.
# In 2024, the best exponent was 1.85. For MVC, it was 2.37, which is a difference of +0.52.
# In 2024, the best exponent was 1.85. For Mountain West, it was 1.76, which is a difference of -0.09.
# In 2024, the best exponent was 1.85. For NEC, it was 2.15, which is a difference of +0.30.
# In 2024, the best exponent was 1.85. For OVC, it was 1.80, which is a difference of -0.05.
# In 2024, the best exponent was 1.85. For Pac-12, it was 2.08, which is a difference of +0.23.
# In 2024, the best exponent was 1.85. For Patriot, it was 1.24, which is a difference of -0.61.
# In 2024, the best exponent was 1.85. For SEC, it was 1.90, which is a difference of +0.05.
# In 2024, the best exponent was 1.85. For SWAC, it was 1.75, which is a difference of -0.10.
# In 2024, the best exponent was 1.85. For SoCon, it was 1.69, which is a difference of -0.16.
# In 2024, the best exponent was 1.85. For Southland, it was 1.59, which is a difference of -0.26.
# In 2024, the best exponent was 1.85. For Summit League, it was 2.07, which is a difference of +0.22.
# In 2024, the best exponent was 1.85. For Sun Belt, it was 1.65, which is a difference of -0.20.
# In 2024, the best exponent was 1.85. For The American, it was 1.73, which is a difference of -0.12.
# In 2024, the best exponent was 1.85. For WAC, it was 1.70, which is a difference of -0.15.
# In 2024, the best exponent was 1.85. For WCC, it was 1.77, which is a difference of -0.08.
# In 2025, the best exponent was 1.80. For ACC, it was 1.76, which is a difference of -0.04.
# In 2025, the best exponent was 1.80. For ASUN, it was 1.91, which is a difference of +0.11.
# In 2025, the best exponent was 1.80. For America East, it was 1.73, which is a difference of -0.07.
# In 2025, the best exponent was 1.80. For Atlantic 10, it was 1.69, which is a difference of -0.11.
# In 2025, the best exponent was 1.80. For Big 12, it was 1.66, which is a difference of -0.14.
# In 2025, the best exponent was 1.80. For Big East, it was 2.16, which is a difference of +0.36.
# In 2025, the best exponent was 1.80. For Big South, it was 1.58, which is a difference of -0.22.
# In 2025, the best exponent was 1.80. For Big Ten, it was 1.45, which is a difference of -0.35.
# In 2025, the best exponent was 1.80. For Big West, it was 1.90, which is a difference of +0.10.
# In 2025, the best exponent was 1.80. For CAA, it was 1.70, which is a difference of -0.10.
# In 2025, the best exponent was 1.80. For CUSA, it was 1.78, which is a difference of -0.02.
# In 2025, the best exponent was 1.80. For Horizon, it was 2.47, which is a difference of +0.67.
# In 2025, the best exponent was 1.80. For Ivy League, it was 1.58, which is a difference of -0.22.
# In 2025, the best exponent was 1.80. For MAAC, it was 1.81, which is a difference of +0.01.
# In 2025, the best exponent was 1.80. For MAC, it was 2.19, which is a difference of +0.39.
# In 2025, the best exponent was 1.80. For MVC, it was 2.12, which is a difference of +0.32.
# In 2025, the best exponent was 1.80. For Mountain West, it was 1.85, which is a difference of +0.05.
# In 2025, the best exponent was 1.80. For NEC, it was 2.12, which is a difference of +0.32.
# In 2025, the best exponent was 1.80. For OVC, it was 2.19, which is a difference of +0.39.
# In 2025, the best exponent was 1.80. For Patriot, it was 1.65, which is a difference of -0.15.
# In 2025, the best exponent was 1.80. For SEC, it was 1.60, which is a difference of -0.20.
# In 2025, the best exponent was 1.80. For SWAC, it was 2.10, which is a difference of +0.30.
# In 2025, the best exponent was 1.80. For SoCon, it was 1.19, which is a difference of -0.61.
# In 2025, the best exponent was 1.80. For Southland, it was 1.79, which is a difference of -0.01.
# In 2025, the best exponent was 1.80. For Summit League, it was 2.25, which is a difference of +0.45.
# In 2025, the best exponent was 1.80. For Sun Belt, it was 1.88, which is a difference of +0.08.
# In 2025, the best exponent was 1.80. For The American, it was 2.12, which is a difference of +0.32.
# In 2025, the best exponent was 1.80. For WAC, it was 1.30, which is a difference of -0.50.
# In 2025, the best exponent was 1.80. For WCC, it was 1.63, which is a difference of -0.17.
#
# Average differences by conference:
# ACC: avg diff = -0.094, std = 0.135, n=5
# ASUN: avg diff = +0.070, std = 0.124, n=5
# America East: avg diff = -0.010, std = 0.285, n=5
# Atlantic 10: avg diff = +0.050, std = 0.156, n=5
# Big 12: avg diff = -0.214, std = 0.055, n=5
# Big East: avg diff = +0.042, std = 0.173, n=5
# Big South: avg diff = +0.006, std = 0.116, n=5
# Big Ten: avg diff = -0.166, std = 0.161, n=5
# Big West: avg diff = +0.140, std = 0.127, n=5
# CAA: avg diff = -0.118, std = 0.092, n=5
# CUSA: avg diff = +0.098, std = 0.113, n=5
# Horizon: avg diff = +0.080, std = 0.311, n=5
# MAAC: avg diff = +0.058, std = 0.100, n=5
# MAC: avg diff = +0.146, std = 0.152, n=5
# MEAC: avg diff = +0.060, std = 0.110, n=2
# MVC: avg diff = +0.272, std = 0.164, n=5
# Mountain West: avg diff = -0.174, std = 0.436, n=5
# NEC: avg diff = +0.208, std = 0.168, n=5
# OVC: avg diff = +0.190, std = 0.426, n=5
# Pac-12: avg diff = +0.005, std = 0.139, n=4
# Patriot: avg diff = -0.146, std = 0.512, n=5
# SEC: avg diff = -0.068, std = 0.176, n=5
# SWAC: avg diff = -0.018, std = 0.166, n=5
# SoCon: avg diff = -0.132, std = 0.277, n=5
# Southland: avg diff = -0.232, std = 0.210, n=5
# Summit League: avg diff = +0.210, std = 0.136, n=5
# Sun Belt: avg diff = +0.034, std = 0.160, n=5
# The American: avg diff = +0.102, std = 0.142, n=5
# WAC: avg diff = -0.062, std = 0.302, n=5
# WCC: avg diff = -0.008, std = 0.122, n=5
# Ivy League: avg diff = +0.020, std = 0.201, n=4
